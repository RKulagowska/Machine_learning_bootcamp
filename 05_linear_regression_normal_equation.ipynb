# %% [markdown]
# <a href="https://colab.research.google.com/github/RKulagowska/Machine_learning_bootcamp/blob/main/05_linear_regression_normal_equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import bibliotek

# %%
import numpy as np

# %% [markdown]
# # Przygotowanie danych

# %%
x1 = np.array([1,2,3,4,5,6])
y = np.array([3000,3250,3500,3750,4000,4250])
m = len(x1)

print(f'Lata pracy: {x1}')
print(f'Wynagrodzenie: {y}')
print(f'Liczba próbek: {m}')
# Out:
# Lata pracy: [1 2 3 4 5 6]
# Wynagrodzenie: [3000 3250 3500 3750 4000 4250]
# Liczba próbek: 6

# %%
x1 = x1.reshape(m,1)
print(x1)
print(x1.shape)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]
#  [6]]
# (6, 1)

# %%
bias = np.ones((m,1))
print(bias)
print(bias.shape)
# Out:
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]]
# (6, 1)

# %%
x= np.append(bias,x1,axis=1)
print(x)
print(x.shape)
# Out:
# [[1. 1.]
#  [1. 2.]
#  [1. 3.]
#  [1. 4.]
#  [1. 5.]
#  [1. 6.]]
# (6, 2)

# %% [markdown]
# # Równanie normalne

# %% [markdown]
# ![regresja liniowa.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![x.JPG](data:image/jpeg;base64,...)

# %%
np.dot(x.T,x)
# Out:
# array([[ 6., 21.],
#        [21., 91.]])

# %% [markdown]
# ![xodwr.JPG](data:image/jpeg;base64,...)

# %%
L = np.linalg.inv(np.dot(x.T,x))
L
# Out:
# array([[ 0.86666667, -0.2       ],
#        [-0.2       ,  0.05714286]])

# %% [markdown]
# ![y.JPG](data:image/jpeg;base64,...)

# %%
P = np.dot(x.T,y)
P
# Out:
# array([21750., 80500.])

# %% [markdown]
# ![caly.JPG](data:image/jpeg;base64,...)

# %%
np.dot(L,P)
# Out:
# array([2750.,  250.])

# %% [markdown]
# Końcowa postać modelu
# ![postać kon.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # Regresja liniowa przy pomocy Scikit-learn

# %%
from  sklearn.linear_model import LinearRegression

regression = LinearRegression()
regression.fit(x1,y)

print(regression.intercept_)
print(regression.coef_[0])
# Out:
# 2750.0
# 250.0
